# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns

# pakai scalecast untuk mempermudah plot series dan eksploratory time series
# pip install scalecast==0.5.2

from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf

# tensorflow untuk LSTM
import tensorflow as tf
# Out:
# 2022-07-24 22:44:07.566802: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-07-24 22:44:07.566863: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
df = pd.read_excel("./traffic_dan_covid_negara.xlsx")
df_country = df["traffic-canada"]
df_country.index = df["Date"]

# %%
sns.set(rc={'figure.figsize': (15, 8)})
sns.lineplot(x=df_country.index, y=df_country)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='traffic-canada'>

# %%
sns.set(rc={'figure.figsize': (15, 8)})
sns.lineplot(x=df_country.index, y=df_country)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='traffic-canada'>

# %%
temp = seasonal_decompose(df_country.asfreq(freq='d'))
temp.plot()

# %%
window_size = 14
plot_acf(df_country.asfreq(freq='d'), lags=window_size)

# %%
# Tidak ada trend, namun memiliki seasonal

# %%
df_country = df_country.to_numpy().reshape(-1,1)

# %%
# Memisahkan Train, Validasi, Test

# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0, 1))
df_scaled = sc.fit_transform(df_country)

# %%
xdata = []
ydata = []

for i in range(window_size, len(df_scaled)):
    xdata.append(df_scaled[i-window_size:i])
    ydata.append(df_scaled[i])

xdata, ydata = np.array(xdata), np.array(ydata)

# %%
xdata = np.reshape(xdata, (xdata.shape[0], xdata.shape[1], 1))

# %%
xtrain, xval, xtest = xdata[0:-(window_size*10)
                            ], xdata[-(window_size*10):-(window_size*5)], xdata[-(window_size*5):]

ytrain, yval, ytest = ydata[0:-(window_size*10)
                            ], ydata[-(window_size*10):-(window_size*5)], ydata[-(window_size*5):]

# %%
xdata.shape
# Out:
# (248, 14, 1)

# %%
ydata.shape
# Out:
# (248, 1)

# %%
batch_size = 16

# %%
tf.keras.backend.clear_session()

model_tune = tf.keras.models.Sequential([
    tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                           input_shape=[window_size]),
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(200, return_sequences=True)),
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(200, return_sequences=True)),
    # tf.keras.layers.Bidirectional(
    #     tf.keras.layers.LSTM(200, return_sequences=True)),
    # tf.keras.layers.Bidirectional(
    #     tf.keras.layers.LSTM(200, return_sequences=True)),
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(200)),
    tf.keras.layers.Dense(1)
])

# Print the model summary
model_tune.summary()

# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-4 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(momentum=0.9)

# Set the training parameters
model_tune.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer, metrics=["mae"])

# Train the model
history = model_tune.fit(xtrain, ytrain, validation_data=(xval, yval), epochs=100, batch_size=batch_size, validation_batch_size=batch_size, callbacks=[lr_schedule])
# Out:
# 2022-07-24 22:44:21.787063: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-24 22:44:21.787678: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-07-24 22:44:21.787834: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-07-24 22:44:21.787928: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-07-24 22:44:21.788019: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-07-24 22:44:21.788113: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-07-24 22:44:21.788201: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-07-24 22:44:21.788292: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-07-24 22:44:21.788379: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-07-24 22:44:21.788394: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-07-24 22:44:21.788729: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lambda (Lambda)             (None, 14, 1)             0
#
#  bidirectional (Bidirectiona  (None, 14, 400)          323200
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 14, 400)          961600
#  nal)
#
#  bidirectional_2 (Bidirectio  (None, 400)              961600
#  nal)
#
#  dense (Dense)               (None, 1)                 401
#
# =================================================================
# Total params: 2,246,801
# Trainable params: 2,246,801
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 7/7 [==============================] - 20s 1s/step - loss: 0.2767 - mae: 0.7238 - val_loss: 0.3191 - val_mae: 0.7827 - lr: 1.0000e-04
# Epoch 2/100
# 7/7 [==============================] - 1s 196ms/step - loss: 0.2682 - mae: 0.7118 - val_loss: 0.3059 - val_mae: 0.7657 - lr: 1.1220e-04
# Epoch 3/100
# 7/7 [==============================] - 1s 189ms/step - loss: 0.2546 - mae: 0.6927 - val_loss: 0.2889 - val_mae: 0.7438 - lr: 1.2589e-04
# Epoch 4/100
# 7/7 [==============================] - 1s 189ms/step - loss: 0.2384 - mae: 0.6687 - val_loss: 0.2694 - val_mae: 0.7178 - lr: 1.4125e-04
# Epoch 5/100
# 7/7 [==============================] - 1s 200ms/step - loss: 0.2203 - mae: 0.6411 - val_loss: 0.2486 - val_mae: 0.6889 - lr: 1.5849e-04
# Epoch 6/100
# 7/7 [==============================] - 2s 334ms/step - loss: 0.2011 - mae: 0.6108 - val_loss: 0.2268 - val_mae: 0.6574 - lr: 1.7783e-04
# Epoch 7/100
# 7/7 [==============================] - 4s 592ms/step - loss: 0.1815 - mae: 0.5788 - val_loss: 0.2045 - val_mae: 0.6233 - lr: 1.9953e-04
# Epoch 8/100
# 7/7 [==============================] - 5s 758ms/step - loss: 0.1616 - mae: 0.5454 - val_loss: 0.1820 - val_mae: 0.5869 - lr: 2.2387e-04
# Epoch 9/100
# 7/7 [==============================] - 4s 595ms/step - loss: 0.1418 - mae: 0.5096 - val_loss: 0.1596 - val_mae: 0.5487 - lr: 2.5119e-04
# Epoch 10/100
# 7/7 [==============================] - 5s 705ms/step - loss: 0.1225 - mae: 0.4728 - val_loss: 0.1378 - val_mae: 0.5091 - lr: 2.8184e-04
# Epoch 11/100
# 7/7 [==============================] - 4s 612ms/step - loss: 0.1037 - mae: 0.4332 - val_loss: 0.1170 - val_mae: 0.4681 - lr: 3.1623e-04
# Epoch 12/100
# 7/7 [==============================] - 4s 592ms/step - loss: 0.0864 - mae: 0.3929 - val_loss: 0.0974 - val_mae: 0.4255 - lr: 3.5481e-04
# Epoch 13/100
# 7/7 [==============================] - 4s 582ms/step - loss: 0.0701 - mae: 0.3523 - val_loss: 0.0797 - val_mae: 0.3826 - lr: 3.9811e-04
# Epoch 14/100
# 7/7 [==============================] - 4s 592ms/step - loss: 0.0557 - mae: 0.3119 - val_loss: 0.0642 - val_mae: 0.3398 - lr: 4.4668e-04
# Epoch 15/100
# 7/7 [==============================] - 4s 586ms/step - loss: 0.0441 - mae: 0.2729 - val_loss: 0.0504 - val_mae: 0.2961 - lr: 5.0119e-04
# Epoch 16/100
# 7/7 [==============================] - 4s 592ms/step - loss: 0.0340 - mae: 0.2358 - val_loss: 0.0392 - val_mae: 0.2539 - lr: 5.6234e-04
# Epoch 17/100
# 7/7 [==============================] - 4s 598ms/step - loss: 0.0265 - mae: 0.2023 - val_loss: 0.0304 - val_mae: 0.2158 - lr: 6.3096e-04
# Epoch 18/100
# 7/7 [==============================] - 4s 647ms/step - loss: 0.0209 - mae: 0.1733 - val_loss: 0.0240 - val_mae: 0.1876 - lr: 7.0795e-04
# Epoch 19/100
# 7/7 [==============================] - 4s 600ms/step - loss: 0.0172 - mae: 0.1512 - val_loss: 0.0198 - val_mae: 0.1684 - lr: 7.9433e-04
# Epoch 20/100
# 7/7 [==============================] - 4s 591ms/step - loss: 0.0151 - mae: 0.1365 - val_loss: 0.0172 - val_mae: 0.1557 - lr: 8.9125e-04
# Epoch 21/100
# 7/7 [==============================] - 4s 594ms/step - loss: 0.0144 - mae: 0.1290 - val_loss: 0.0154 - val_mae: 0.1459 - lr: 0.0010
# Epoch 22/100
# 7/7 [==============================] - 4s 601ms/step - loss: 0.0140 - mae: 0.1223 - val_loss: 0.0144 - val_mae: 0.1400 - lr: 0.0011
# Epoch 23/100
# 7/7 [==============================] - 4s 604ms/step - loss: 0.0139 - mae: 0.1201 - val_loss: 0.0140 - val_mae: 0.1372 - lr: 0.0013
# Epoch 24/100
# 7/7 [==============================] - 5s 741ms/step - loss: 0.0138 - mae: 0.1195 - val_loss: 0.0140 - val_mae: 0.1372 - lr: 0.0014
# Epoch 25/100
# 7/7 [==============================] - 4s 597ms/step - loss: 0.0138 - mae: 0.1194 - val_loss: 0.0141 - val_mae: 0.1372 - lr: 0.0016
# Epoch 26/100
# 7/7 [==============================] - 4s 598ms/step - loss: 0.0138 - mae: 0.1195 - val_loss: 0.0141 - val_mae: 0.1378 - lr: 0.0018
# Epoch 27/100
# 7/7 [==============================] - 4s 589ms/step - loss: 0.0138 - mae: 0.1197 - val_loss: 0.0142 - val_mae: 0.1380 - lr: 0.0020
# Epoch 28/100
# 7/7 [==============================] - 4s 596ms/step - loss: 0.0139 - mae: 0.1196 - val_loss: 0.0140 - val_mae: 0.1371 - lr: 0.0022
# Epoch 29/100
# 7/7 [==============================] - 4s 566ms/step - loss: 0.0138 - mae: 0.1196 - val_loss: 0.0143 - val_mae: 0.1392 - lr: 0.0025
# Epoch 30/100
# 7/7 [==============================] - 1s 188ms/step - loss: 0.0138 - mae: 0.1204 - val_loss: 0.0144 - val_mae: 0.1396 - lr: 0.0028
# Epoch 31/100
# 7/7 [==============================] - 1s 184ms/step - loss: 0.0138 - mae: 0.1206 - val_loss: 0.0145 - val_mae: 0.1403 - lr: 0.0032
# Epoch 32/100
# 7/7 [==============================] - 1s 182ms/step - loss: 0.0138 - mae: 0.1207 - val_loss: 0.0144 - val_mae: 0.1397 - lr: 0.0035
# Epoch 33/100
# 7/7 [==============================] - 1s 185ms/step - loss: 0.0140 - mae: 0.1225 - val_loss: 0.0146 - val_mae: 0.1414 - lr: 0.0040
# Epoch 34/100
# 7/7 [==============================] - 3s 536ms/step - loss: 0.0138 - mae: 0.1198 - val_loss: 0.0140 - val_mae: 0.1369 - lr: 0.0045
# Epoch 35/100
# 7/7 [==============================] - 4s 654ms/step - loss: 0.0138 - mae: 0.1191 - val_loss: 0.0139 - val_mae: 0.1360 - lr: 0.0050
# Epoch 36/100
# 7/7 [==============================] - 4s 582ms/step - loss: 0.0138 - mae: 0.1191 - val_loss: 0.0141 - val_mae: 0.1375 - lr: 0.0056
# Epoch 37/100
# 7/7 [==============================] - 4s 595ms/step - loss: 0.0138 - mae: 0.1194 - val_loss: 0.0141 - val_mae: 0.1374 - lr: 0.0063
# Epoch 38/100
# 7/7 [==============================] - 4s 594ms/step - loss: 0.0138 - mae: 0.1202 - val_loss: 0.0142 - val_mae: 0.1381 - lr: 0.0071
# Epoch 39/100
# 7/7 [==============================] - 5s 707ms/step - loss: 0.0138 - mae: 0.1199 - val_loss: 0.0143 - val_mae: 0.1391 - lr: 0.0079
# Epoch 40/100
# 7/7 [==============================] - 4s 565ms/step - loss: 0.0137 - mae: 0.1194 - val_loss: 0.0141 - val_mae: 0.1376 - lr: 0.0089
# Epoch 41/100
# 7/7 [==============================] - 4s 602ms/step - loss: 0.0137 - mae: 0.1189 - val_loss: 0.0141 - val_mae: 0.1376 - lr: 0.0100
# Epoch 42/100
# 7/7 [==============================] - 4s 594ms/step - loss: 0.0137 - mae: 0.1208 - val_loss: 0.0145 - val_mae: 0.1404 - lr: 0.0112
# Epoch 43/100
# 7/7 [==============================] - 4s 597ms/step - loss: 0.0139 - mae: 0.1206 - val_loss: 0.0139 - val_mae: 0.1355 - lr: 0.0126
# Epoch 44/100
# 7/7 [==============================] - 4s 595ms/step - loss: 0.0141 - mae: 0.1225 - val_loss: 0.0146 - val_mae: 0.1410 - lr: 0.0141
# Epoch 45/100
# 7/7 [==============================] - 4s 604ms/step - loss: 0.0137 - mae: 0.1191 - val_loss: 0.0136 - val_mae: 0.1329 - lr: 0.0158
# Epoch 46/100
# 7/7 [==============================] - 4s 600ms/step - loss: 0.0136 - mae: 0.1198 - val_loss: 0.0147 - val_mae: 0.1417 - lr: 0.0178
# Epoch 47/100
# 7/7 [==============================] - 4s 592ms/step - loss: 0.0139 - mae: 0.1239 - val_loss: 0.0137 - val_mae: 0.1339 - lr: 0.0200
# Epoch 48/100
# 7/7 [==============================] - 4s 599ms/step - loss: 0.0142 - mae: 0.1190 - val_loss: 0.0140 - val_mae: 0.1362 - lr: 0.0224
# Epoch 49/100
# 7/7 [==============================] - 4s 612ms/step - loss: 0.0137 - mae: 0.1209 - val_loss: 0.0142 - val_mae: 0.1382 - lr: 0.0251
# Epoch 50/100
# 7/7 [==============================] - 4s 655ms/step - loss: 0.0137 - mae: 0.1184 - val_loss: 0.0141 - val_mae: 0.1370 - lr: 0.0282
# Epoch 51/100
# 7/7 [==============================] - 4s 606ms/step - loss: 0.0134 - mae: 0.1190 - val_loss: 0.0145 - val_mae: 0.1404 - lr: 0.0316
# Epoch 52/100
# 7/7 [==============================] - 4s 590ms/step - loss: 0.0135 - mae: 0.1191 - val_loss: 0.0142 - val_mae: 0.1381 - lr: 0.0355
# Epoch 53/100
# 7/7 [==============================] - 5s 689ms/step - loss: 0.0137 - mae: 0.1207 - val_loss: 0.0133 - val_mae: 0.1275 - lr: 0.0398
# Epoch 54/100
# 7/7 [==============================] - 4s 592ms/step - loss: 0.0135 - mae: 0.1203 - val_loss: 0.0153 - val_mae: 0.1457 - lr: 0.0447
# Epoch 55/100
# 7/7 [==============================] - 4s 593ms/step - loss: 0.0137 - mae: 0.1193 - val_loss: 0.0133 - val_mae: 0.1275 - lr: 0.0501
# Epoch 56/100
# 7/7 [==============================] - 4s 601ms/step - loss: 0.0132 - mae: 0.1188 - val_loss: 0.0154 - val_mae: 0.1459 - lr: 0.0562
# Epoch 57/100
# 7/7 [==============================] - 4s 607ms/step - loss: 0.0142 - mae: 0.1236 - val_loss: 0.0146 - val_mae: 0.1405 - lr: 0.0631
# Epoch 58/100
# 7/7 [==============================] - 5s 670ms/step - loss: 0.0131 - mae: 0.1213 - val_loss: 0.0143 - val_mae: 0.1108 - lr: 0.0708
# Epoch 59/100
# 7/7 [==============================] - 2s 282ms/step - loss: 0.0155 - mae: 0.1303 - val_loss: 0.0135 - val_mae: 0.1301 - lr: 0.0794
# Epoch 60/100
# 7/7 [==============================] - 1s 196ms/step - loss: 0.0131 - mae: 0.1157 - val_loss: 0.0186 - val_mae: 0.1627 - lr: 0.0891
# Epoch 61/100
# 7/7 [==============================] - 1s 195ms/step - loss: 0.0142 - mae: 0.1232 - val_loss: 0.0165 - val_mae: 0.1523 - lr: 0.1000
# Epoch 62/100
# 7/7 [==============================] - 1s 189ms/step - loss: 0.0162 - mae: 0.1321 - val_loss: 0.0181 - val_mae: 0.1600 - lr: 0.1122
# Epoch 63/100
# 7/7 [==============================] - 1s 197ms/step - loss: 0.0146 - mae: 0.1277 - val_loss: 0.0174 - val_mae: 0.1568 - lr: 0.1259
# Epoch 64/100
# 7/7 [==============================] - 1s 196ms/step - loss: 0.0136 - mae: 0.1279 - val_loss: 0.0183 - val_mae: 0.1183 - lr: 0.1413
# Epoch 65/100
# 7/7 [==============================] - 1s 196ms/step - loss: 0.0153 - mae: 0.1248 - val_loss: 0.0170 - val_mae: 0.1546 - lr: 0.1585
# Epoch 66/100
# 7/7 [==============================] - 1s 196ms/step - loss: 0.0142 - mae: 0.1238 - val_loss: 0.0191 - val_mae: 0.1653 - lr: 0.1778
# Epoch 67/100
# 7/7 [==============================] - 1s 200ms/step - loss: 0.0133 - mae: 0.1196 - val_loss: 0.0176 - val_mae: 0.1576 - lr: 0.1995
# Epoch 68/100
# 7/7 [==============================] - 1s 203ms/step - loss: 0.0139 - mae: 0.1235 - val_loss: 0.0141 - val_mae: 0.1356 - lr: 0.2239
# Epoch 69/100
# 7/7 [==============================] - 1s 202ms/step - loss: 0.0134 - mae: 0.1234 - val_loss: 0.0166 - val_mae: 0.1528 - lr: 0.2512
# Epoch 70/100
# 7/7 [==============================] - 2s 230ms/step - loss: 0.0130 - mae: 0.1191 - val_loss: 0.0162 - val_mae: 0.1504 - lr: 0.2818
# Epoch 71/100
# 7/7 [==============================] - 1s 199ms/step - loss: 0.0177 - mae: 0.1468 - val_loss: 0.0198 - val_mae: 0.1257 - lr: 0.3162
# Epoch 72/100
# 7/7 [==============================] - 1s 198ms/step - loss: 0.0184 - mae: 0.1372 - val_loss: 0.0268 - val_mae: 0.2001 - lr: 0.3548
# Epoch 73/100
# 7/7 [==============================] - 3s 410ms/step - loss: 0.0157 - mae: 0.1338 - val_loss: 0.0227 - val_mae: 0.1820 - lr: 0.3981
# Epoch 74/100
# 7/7 [==============================] - 4s 484ms/step - loss: 0.0224 - mae: 0.1690 - val_loss: 0.0134 - val_mae: 0.1141 - lr: 0.4467
# Epoch 75/100
# 7/7 [==============================] - 1s 194ms/step - loss: 0.0188 - mae: 0.1439 - val_loss: 0.0143 - val_mae: 0.1397 - lr: 0.5012
# Epoch 76/100
# 7/7 [==============================] - 1s 190ms/step - loss: 0.0142 - mae: 0.1218 - val_loss: 0.0138 - val_mae: 0.1352 - lr: 0.5623
# Epoch 77/100
# 7/7 [==============================] - 1s 198ms/step - loss: 0.0150 - mae: 0.1239 - val_loss: 0.0201 - val_mae: 0.1700 - lr: 0.6310
# Epoch 78/100
# 7/7 [==============================] - 1s 183ms/step - loss: 0.0219 - mae: 0.1626 - val_loss: 0.0176 - val_mae: 0.1139 - lr: 0.7079
# Epoch 79/100
# 7/7 [==============================] - 1s 185ms/step - loss: 0.0239 - mae: 0.1674 - val_loss: 0.0174 - val_mae: 0.1126 - lr: 0.7943
# Epoch 80/100
# 7/7 [==============================] - 1s 187ms/step - loss: 0.0314 - mae: 0.1948 - val_loss: 0.0295 - val_mae: 0.2117 - lr: 0.8913
# Epoch 81/100
# 7/7 [==============================] - 1s 187ms/step - loss: 0.0229 - mae: 0.1774 - val_loss: 0.0252 - val_mae: 0.1924 - lr: 1.0000
# Epoch 82/100
# 7/7 [==============================] - 1s 186ms/step - loss: 0.0265 - mae: 0.1769 - val_loss: 0.0139 - val_mae: 0.1362 - lr: 1.1220
# Epoch 83/100
# 7/7 [==============================] - 1s 187ms/step - loss: 0.0174 - mae: 0.1487 - val_loss: 0.0138 - val_mae: 0.1353 - lr: 1.2589
# Epoch 84/100
# 7/7 [==============================] - 1s 186ms/step - loss: 0.0189 - mae: 0.1445 - val_loss: 0.0179 - val_mae: 0.1590 - lr: 1.4125
# Epoch 85/100
# 7/7 [==============================] - 1s 181ms/step - loss: 0.0308 - mae: 0.1976 - val_loss: 0.0287 - val_mae: 0.1781 - lr: 1.5849
# Epoch 86/100
# 7/7 [==============================] - 1s 179ms/step - loss: 0.0270 - mae: 0.1833 - val_loss: 0.0289 - val_mae: 0.1790 - lr: 1.7783
# Epoch 87/100
# 7/7 [==============================] - 1s 180ms/step - loss: 0.0536 - mae: 0.2651 - val_loss: 0.6637 - val_mae: 1.1599 - lr: 1.9953
# Epoch 88/100
# 7/7 [==============================] - 1s 187ms/step - loss: 25.7148 - mae: 26.2146 - val_loss: 14.6842 - val_mae: 15.1842 - lr: 2.2387
# Epoch 89/100
# 7/7 [==============================] - 1s 191ms/step - loss: 255.7517 - mae: 256.2517 - val_loss: 7.1804 - val_mae: 7.6804 - lr: 2.5119
# Epoch 90/100
# 7/7 [==============================] - 2s 216ms/step - loss: 424.5184 - mae: 425.0184 - val_loss: 245.5640 - val_mae: 246.0640 - lr: 2.8184
# Epoch 91/100
# 7/7 [==============================] - 1s 186ms/step - loss: 170.4077 - mae: 170.9077 - val_loss: 33.4021 - val_mae: 33.9021 - lr: 3.1623
# Epoch 92/100
# 7/7 [==============================] - 1s 185ms/step - loss: 155.9828 - mae: 156.4828 - val_loss: 564.3591 - val_mae: 564.8591 - lr: 3.5481
# Epoch 93/100
# 7/7 [==============================] - 1s 185ms/step - loss: 325.2294 - mae: 325.7294 - val_loss: 109.8872 - val_mae: 110.3872 - lr: 3.9811
# Epoch 94/100
# 7/7 [==============================] - 1s 189ms/step - loss: 111.0006 - mae: 111.5006 - val_loss: 44.0448 - val_mae: 44.5448 - lr: 4.4668
# Epoch 95/100
# 7/7 [==============================] - 1s 189ms/step - loss: 357.3364 - mae: 357.8364 - val_loss: 584.4365 - val_mae: 584.9365 - lr: 5.0119
# Epoch 96/100
# 7/7 [==============================] - 1s 179ms/step - loss: 511.7518 - mae: 512.2518 - val_loss: 353.8115 - val_mae: 354.3115 - lr: 5.6234
# Epoch 97/100
# 7/7 [==============================] - 1s 178ms/step - loss: 575.4745 - mae: 575.9745 - val_loss: 329.5046 - val_mae: 330.0046 - lr: 6.3096
# Epoch 98/100
# 7/7 [==============================] - 1s 177ms/step - loss: 299.3061 - mae: 299.8061 - val_loss: 824.5391 - val_mae: 825.0391 - lr: 7.0795
# Epoch 99/100
# 7/7 [==============================] - 1s 181ms/step - loss: 928.4860 - mae: 928.9860 - val_loss: 2256.4180 - val_mae: 2256.9180 - lr: 7.9433
# Epoch 100/100
# 7/7 [==============================] - 1s 184ms/step - loss: 1227.2316 - mae: 1227.7316 - val_loss: 108.5093 - val_mae: 109.0093 - lr: 8.9125

# %%
# Define the learning rate array
lrs = 1e-4 * (10 ** (np.arange(100) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the loss in log scale
plt.semilogx(lrs, history.history["loss"])

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-4, 10, 0, 1])
# Out:
# (0.0001, 10.0, 0.0, 1.0)

# %%
tf.keras.backend.clear_session()

# %%
# Build the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                           input_shape=[window_size]),
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(200, return_sequences=True)),
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(200, return_sequences=True)),
    # tf.keras.layers.Bidirectional(
    #     tf.keras.layers.LSTM(200, return_sequences=True)),
    # tf.keras.layers.Bidirectional(
    #     tf.keras.layers.LSTM(200, return_sequences=True)),
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(200)),
    tf.keras.layers.Dense(1)
])

# Set the learning rate
learning_rate = 1e-1

# Set the optimizer 
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# Train the model
history = model.fit(xtrain, ytrain, validation_data=(xval, yval), epochs=100, batch_size=batch_size, validation_batch_size=batch_size)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 12s 532ms/step - loss: 0.1049 - mae: 0.3777 - val_loss: 0.0884 - val_mae: 0.4043
# Epoch 2/100
# 7/7 [==============================] - 1s 177ms/step - loss: 0.0473 - mae: 0.2467 - val_loss: 0.0303 - val_mae: 0.1865
# Epoch 3/100
# 7/7 [==============================] - 1s 177ms/step - loss: 0.0279 - mae: 0.1884 - val_loss: 0.0386 - val_mae: 0.2516
# Epoch 4/100
# 7/7 [==============================] - 1s 175ms/step - loss: 0.0204 - mae: 0.1585 - val_loss: 0.0139 - val_mae: 0.1099
# Epoch 5/100
# 7/7 [==============================] - 1s 175ms/step - loss: 0.0167 - mae: 0.1354 - val_loss: 0.0212 - val_mae: 0.1746
# Epoch 6/100
# 7/7 [==============================] - 1s 174ms/step - loss: 0.0155 - mae: 0.1318 - val_loss: 0.0133 - val_mae: 0.1302
# Epoch 7/100
# 7/7 [==============================] - 1s 177ms/step - loss: 0.0157 - mae: 0.1286 - val_loss: 0.0168 - val_mae: 0.1533
# Epoch 8/100
# 7/7 [==============================] - 1s 224ms/step - loss: 0.0144 - mae: 0.1247 - val_loss: 0.0137 - val_mae: 0.1347
# Epoch 9/100
# 7/7 [==============================] - 1s 174ms/step - loss: 0.0149 - mae: 0.1231 - val_loss: 0.0156 - val_mae: 0.1470
# Epoch 10/100
# 7/7 [==============================] - 1s 172ms/step - loss: 0.0145 - mae: 0.1240 - val_loss: 0.0146 - val_mae: 0.1415
# Epoch 11/100
# 7/7 [==============================] - 1s 172ms/step - loss: 0.0146 - mae: 0.1245 - val_loss: 0.0142 - val_mae: 0.1389
# Epoch 12/100
# 7/7 [==============================] - 1s 174ms/step - loss: 0.0146 - mae: 0.1266 - val_loss: 0.0148 - val_mae: 0.1426
# Epoch 13/100
# 7/7 [==============================] - 1s 178ms/step - loss: 0.0152 - mae: 0.1226 - val_loss: 0.0147 - val_mae: 0.1422
# Epoch 14/100
# 7/7 [==============================] - 1s 178ms/step - loss: 0.0145 - mae: 0.1272 - val_loss: 0.0152 - val_mae: 0.1447
# Epoch 15/100
# 7/7 [==============================] - 1s 180ms/step - loss: 0.0143 - mae: 0.1239 - val_loss: 0.0140 - val_mae: 0.1374
# Epoch 16/100
# 7/7 [==============================] - 1s 180ms/step - loss: 0.0144 - mae: 0.1219 - val_loss: 0.0139 - val_mae: 0.1365
# Epoch 17/100
# 7/7 [==============================] - 1s 178ms/step - loss: 0.0142 - mae: 0.1207 - val_loss: 0.0149 - val_mae: 0.1435
# Epoch 18/100
# 7/7 [==============================] - 1s 177ms/step - loss: 0.0147 - mae: 0.1281 - val_loss: 0.0142 - val_mae: 0.1383
# Epoch 19/100
# 7/7 [==============================] - 1s 174ms/step - loss: 0.0142 - mae: 0.1220 - val_loss: 0.0148 - val_mae: 0.1425
# Epoch 20/100
# 7/7 [==============================] - 1s 188ms/step - loss: 0.0142 - mae: 0.1226 - val_loss: 0.0141 - val_mae: 0.1377
# Epoch 21/100
# 7/7 [==============================] - 1s 193ms/step - loss: 0.0141 - mae: 0.1204 - val_loss: 0.0147 - val_mae: 0.1419
# Epoch 22/100
# 7/7 [==============================] - 1s 177ms/step - loss: 0.0141 - mae: 0.1212 - val_loss: 0.0144 - val_mae: 0.1397
# Epoch 23/100
# 7/7 [==============================] - 1s 179ms/step - loss: 0.0148 - mae: 0.1269 - val_loss: 0.0141 - val_mae: 0.1374
# Epoch 24/100
# 7/7 [==============================] - 1s 176ms/step - loss: 0.0147 - mae: 0.1223 - val_loss: 0.0153 - val_mae: 0.1455
# Epoch 25/100
# 7/7 [==============================] - 1s 178ms/step - loss: 0.0147 - mae: 0.1314 - val_loss: 0.0144 - val_mae: 0.1399
# Epoch 26/100
# 7/7 [==============================] - 1s 185ms/step - loss: 0.0148 - mae: 0.1233 - val_loss: 0.0145 - val_mae: 0.1407
# Epoch 27/100
# 7/7 [==============================] - 1s 204ms/step - loss: 0.0139 - mae: 0.1205 - val_loss: 0.0142 - val_mae: 0.1388
# Epoch 28/100
# 7/7 [==============================] - 1s 202ms/step - loss: 0.0139 - mae: 0.1199 - val_loss: 0.0147 - val_mae: 0.1422
# Epoch 29/100
# 7/7 [==============================] - 1s 197ms/step - loss: 0.0146 - mae: 0.1268 - val_loss: 0.0132 - val_mae: 0.1288
# Epoch 30/100
# 7/7 [==============================] - 1s 176ms/step - loss: 0.0141 - mae: 0.1217 - val_loss: 0.0154 - val_mae: 0.1463
# Epoch 31/100
# 7/7 [==============================] - 1s 187ms/step - loss: 0.0145 - mae: 0.1231 - val_loss: 0.0131 - val_mae: 0.1248
# Epoch 32/100
# 7/7 [==============================] - 1s 206ms/step - loss: 0.0138 - mae: 0.1196 - val_loss: 0.0163 - val_mae: 0.1510
# Epoch 33/100
# 7/7 [==============================] - 1s 188ms/step - loss: 0.0137 - mae: 0.1239 - val_loss: 0.0133 - val_mae: 0.1286
# Epoch 34/100
# 7/7 [==============================] - 1s 198ms/step - loss: 0.0142 - mae: 0.1225 - val_loss: 0.0143 - val_mae: 0.1394
# Epoch 35/100
# 7/7 [==============================] - 1s 184ms/step - loss: 0.0136 - mae: 0.1196 - val_loss: 0.0140 - val_mae: 0.1363
# Epoch 36/100
# 7/7 [==============================] - 1s 187ms/step - loss: 0.0141 - mae: 0.1178 - val_loss: 0.0154 - val_mae: 0.1465
# Epoch 37/100
# 7/7 [==============================] - 1s 186ms/step - loss: 0.0143 - mae: 0.1323 - val_loss: 0.0132 - val_mae: 0.1270
# Epoch 38/100
# 7/7 [==============================] - 1s 183ms/step - loss: 0.0153 - mae: 0.1208 - val_loss: 0.0176 - val_mae: 0.1575
# Epoch 39/100
# 7/7 [==============================] - 1s 182ms/step - loss: 0.0167 - mae: 0.1469 - val_loss: 0.0135 - val_mae: 0.1139
# Epoch 40/100
# 7/7 [==============================] - 1s 189ms/step - loss: 0.0146 - mae: 0.1246 - val_loss: 0.0156 - val_mae: 0.1475
# Epoch 41/100
# 7/7 [==============================] - 1s 187ms/step - loss: 0.0134 - mae: 0.1234 - val_loss: 0.0131 - val_mae: 0.1214
# Epoch 42/100
# 7/7 [==============================] - 1s 185ms/step - loss: 0.0155 - mae: 0.1178 - val_loss: 0.0197 - val_mae: 0.1679
# Epoch 43/100
# 7/7 [==============================] - 1s 219ms/step - loss: 0.0162 - mae: 0.1438 - val_loss: 0.0136 - val_mae: 0.1138
# Epoch 44/100
# 7/7 [==============================] - 1s 180ms/step - loss: 0.0154 - mae: 0.1260 - val_loss: 0.0174 - val_mae: 0.1568
# Epoch 45/100
# 7/7 [==============================] - 1s 182ms/step - loss: 0.0142 - mae: 0.1279 - val_loss: 0.0133 - val_mae: 0.1271
# Epoch 46/100
# 7/7 [==============================] - 1s 183ms/step - loss: 0.0136 - mae: 0.1202 - val_loss: 0.0141 - val_mae: 0.1369
# Epoch 47/100
# 7/7 [==============================] - 1s 181ms/step - loss: 0.0133 - mae: 0.1198 - val_loss: 0.0135 - val_mae: 0.1313
# Epoch 48/100
# 7/7 [==============================] - 1s 181ms/step - loss: 0.0132 - mae: 0.1170 - val_loss: 0.0137 - val_mae: 0.1333
# Epoch 49/100
# 7/7 [==============================] - 1s 184ms/step - loss: 0.0132 - mae: 0.1157 - val_loss: 0.0148 - val_mae: 0.1421
# Epoch 50/100
# 7/7 [==============================] - 1s 187ms/step - loss: 0.0138 - mae: 0.1189 - val_loss: 0.0142 - val_mae: 0.1380
# Epoch 51/100
# 7/7 [==============================] - 1s 183ms/step - loss: 0.0139 - mae: 0.1263 - val_loss: 0.0134 - val_mae: 0.1182
# Epoch 52/100
# 7/7 [==============================] - 1s 181ms/step - loss: 0.0165 - mae: 0.1293 - val_loss: 0.0219 - val_mae: 0.1781
# Epoch 53/100
# 7/7 [==============================] - 1s 179ms/step - loss: 0.0155 - mae: 0.1358 - val_loss: 0.0149 - val_mae: 0.1105
# Epoch 54/100
# 7/7 [==============================] - 1s 185ms/step - loss: 0.0153 - mae: 0.1200 - val_loss: 0.0161 - val_mae: 0.1503
# Epoch 55/100
# 7/7 [==============================] - 1s 209ms/step - loss: 0.0131 - mae: 0.1209 - val_loss: 0.0133 - val_mae: 0.1234
# Epoch 56/100
# 7/7 [==============================] - 1s 186ms/step - loss: 0.0133 - mae: 0.1176 - val_loss: 0.0161 - val_mae: 0.1499
# Epoch 57/100
# 7/7 [==============================] - 1s 180ms/step - loss: 0.0132 - mae: 0.1260 - val_loss: 0.0135 - val_mae: 0.1166
# Epoch 58/100
# 7/7 [==============================] - 1s 180ms/step - loss: 0.0139 - mae: 0.1179 - val_loss: 0.0166 - val_mae: 0.1526
# Epoch 59/100
# 7/7 [==============================] - 1s 184ms/step - loss: 0.0140 - mae: 0.1291 - val_loss: 0.0135 - val_mae: 0.1164
# Epoch 60/100
# 7/7 [==============================] - 1s 186ms/step - loss: 0.0136 - mae: 0.1122 - val_loss: 0.0170 - val_mae: 0.1550
# Epoch 61/100
# 7/7 [==============================] - 1s 177ms/step - loss: 0.0140 - mae: 0.1276 - val_loss: 0.0135 - val_mae: 0.1172
# Epoch 62/100
# 7/7 [==============================] - 1s 182ms/step - loss: 0.0131 - mae: 0.1153 - val_loss: 0.0151 - val_mae: 0.1440
# Epoch 63/100
# 7/7 [==============================] - 1s 180ms/step - loss: 0.0132 - mae: 0.1222 - val_loss: 0.0134 - val_mae: 0.1234
# Epoch 64/100
# 7/7 [==============================] - 2s 215ms/step - loss: 0.0136 - mae: 0.1232 - val_loss: 0.0144 - val_mae: 0.1388
# Epoch 65/100
# 7/7 [==============================] - 1s 186ms/step - loss: 0.0132 - mae: 0.1146 - val_loss: 0.0136 - val_mae: 0.1290
# Epoch 66/100
# 7/7 [==============================] - 1s 181ms/step - loss: 0.0128 - mae: 0.1218 - val_loss: 0.0139 - val_mae: 0.1332
# Epoch 67/100
# 7/7 [==============================] - 1s 182ms/step - loss: 0.0127 - mae: 0.1148 - val_loss: 0.0135 - val_mae: 0.1270
# Epoch 68/100
# 7/7 [==============================] - 1s 185ms/step - loss: 0.0127 - mae: 0.1169 - val_loss: 0.0152 - val_mae: 0.1445
# Epoch 69/100
# 7/7 [==============================] - 1s 182ms/step - loss: 0.0137 - mae: 0.1200 - val_loss: 0.0144 - val_mae: 0.1383
# Epoch 70/100
# 7/7 [==============================] - 1s 186ms/step - loss: 0.0134 - mae: 0.1272 - val_loss: 0.0135 - val_mae: 0.1240
# Epoch 71/100
# 7/7 [==============================] - 1s 186ms/step - loss: 0.0131 - mae: 0.1221 - val_loss: 0.0135 - val_mae: 0.1247
# Epoch 72/100
# 7/7 [==============================] - 1s 180ms/step - loss: 0.0138 - mae: 0.1159 - val_loss: 0.0171 - val_mae: 0.1551
# Epoch 73/100
# 7/7 [==============================] - 1s 179ms/step - loss: 0.0151 - mae: 0.1360 - val_loss: 0.0153 - val_mae: 0.1122
# Epoch 74/100
# 7/7 [==============================] - 1s 191ms/step - loss: 0.0136 - mae: 0.1153 - val_loss: 0.0177 - val_mae: 0.1583
# Epoch 75/100
# 7/7 [==============================] - 1s 180ms/step - loss: 0.0137 - mae: 0.1232 - val_loss: 0.0135 - val_mae: 0.1202
# Epoch 76/100
# 7/7 [==============================] - 1s 187ms/step - loss: 0.0126 - mae: 0.1147 - val_loss: 0.0156 - val_mae: 0.1476
# Epoch 77/100
# 7/7 [==============================] - 1s 182ms/step - loss: 0.0129 - mae: 0.1222 - val_loss: 0.0136 - val_mae: 0.1199
# Epoch 78/100
# 7/7 [==============================] - 1s 183ms/step - loss: 0.0131 - mae: 0.1150 - val_loss: 0.0144 - val_mae: 0.1380
# Epoch 79/100
# 7/7 [==============================] - 1s 183ms/step - loss: 0.0133 - mae: 0.1123 - val_loss: 0.0139 - val_mae: 0.1325
# Epoch 80/100
# 7/7 [==============================] - 1s 184ms/step - loss: 0.0136 - mae: 0.1230 - val_loss: 0.0142 - val_mae: 0.1365
# Epoch 81/100
# 7/7 [==============================] - 1s 182ms/step - loss: 0.0135 - mae: 0.1313 - val_loss: 0.0141 - val_mae: 0.1143
# Epoch 82/100
# 7/7 [==============================] - 1s 185ms/step - loss: 0.0160 - mae: 0.1225 - val_loss: 0.0174 - val_mae: 0.1569
# Epoch 83/100
# 7/7 [==============================] - 1s 213ms/step - loss: 0.0136 - mae: 0.1298 - val_loss: 0.0141 - val_mae: 0.1135
# Epoch 84/100
# 7/7 [==============================] - 1s 185ms/step - loss: 0.0143 - mae: 0.1268 - val_loss: 0.0145 - val_mae: 0.1393
# Epoch 85/100
# 7/7 [==============================] - 1s 180ms/step - loss: 0.0130 - mae: 0.1149 - val_loss: 0.0135 - val_mae: 0.1223
# Epoch 86/100
# 7/7 [==============================] - 1s 179ms/step - loss: 0.0143 - mae: 0.1327 - val_loss: 0.0135 - val_mae: 0.1257
# Epoch 87/100
# 7/7 [==============================] - 1s 186ms/step - loss: 0.0135 - mae: 0.1177 - val_loss: 0.0143 - val_mae: 0.1379
# Epoch 88/100
# 7/7 [==============================] - 1s 187ms/step - loss: 0.0126 - mae: 0.1183 - val_loss: 0.0139 - val_mae: 0.1154
# Epoch 89/100
# 7/7 [==============================] - 1s 189ms/step - loss: 0.0132 - mae: 0.1155 - val_loss: 0.0146 - val_mae: 0.1406
# Epoch 90/100
# 7/7 [==============================] - 1s 193ms/step - loss: 0.0133 - mae: 0.1170 - val_loss: 0.0139 - val_mae: 0.1329
# Epoch 91/100
# 7/7 [==============================] - 1s 193ms/step - loss: 0.0132 - mae: 0.1250 - val_loss: 0.0138 - val_mae: 0.1176
# Epoch 92/100
# 7/7 [==============================] - 1s 185ms/step - loss: 0.0131 - mae: 0.1113 - val_loss: 0.0147 - val_mae: 0.1410
# Epoch 93/100
# 7/7 [==============================] - 1s 192ms/step - loss: 0.0129 - mae: 0.1209 - val_loss: 0.0137 - val_mae: 0.1299
# Epoch 94/100
# 7/7 [==============================] - 1s 184ms/step - loss: 0.0128 - mae: 0.1214 - val_loss: 0.0136 - val_mae: 0.1228
# Epoch 95/100
# 7/7 [==============================] - 1s 189ms/step - loss: 0.0126 - mae: 0.1119 - val_loss: 0.0140 - val_mae: 0.1342
# Epoch 96/100
# 7/7 [==============================] - 1s 185ms/step - loss: 0.0128 - mae: 0.1247 - val_loss: 0.0137 - val_mae: 0.1196
# Epoch 97/100
# 7/7 [==============================] - 1s 189ms/step - loss: 0.0130 - mae: 0.1120 - val_loss: 0.0152 - val_mae: 0.1446
# Epoch 98/100
# 7/7 [==============================] - 1s 187ms/step - loss: 0.0129 - mae: 0.1243 - val_loss: 0.0137 - val_mae: 0.1219
# Epoch 99/100
# 7/7 [==============================] - 1s 191ms/step - loss: 0.0129 - mae: 0.1100 - val_loss: 0.0156 - val_mae: 0.1474
# Epoch 100/100
# 7/7 [==============================] - 1s 189ms/step - loss: 0.0143 - mae: 0.1342 - val_loss: 0.0162 - val_mae: 0.1135

# %%
# summarize history for accuracy
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('model mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
ypred = model.predict(xdata)

plt.plot(ypred)
plt.plot(ydata)
plt.title('prediksi vs aktual semua data')
plt.ylabel('traffic')
plt.xlabel('series')
plt.legend(['prediksi', 'aktual'], loc='upper left')
plt.show()
# Out:
# 8/8 [==============================] - 3s 74ms/step

# %%
ypred = model.predict(xtest)

plt.plot(ypred)
plt.plot(ytest)
plt.title('prediksi vs aktual data testing')
plt.ylabel('traffic')
plt.xlabel('series')
plt.legend(['prediksi', 'aktual'], loc='upper left')
plt.show()
# Out:
# 3/3 [==============================] - 0s 50ms/step
