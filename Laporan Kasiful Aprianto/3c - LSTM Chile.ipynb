# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns

# pakai scalecast untuk mempermudah plot series dan eksploratory time series
# pip install scalecast==0.5.2

from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf

# tensorflow untuk LSTM
import tensorflow as tf
# Out:
# 2022-07-24 23:12:27.743512: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-07-24 23:12:27.743552: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
df = pd.read_excel("./traffic_dan_covid_negara.xlsx")
df_country = df["traffic-chile"]
df_country.index = df["Date"]

# %%
sns.set(rc={'figure.figsize': (15, 8)})
sns.lineplot(x=df_country.index, y=df_country)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='traffic-chile'>

# %%
sns.set(rc={'figure.figsize': (15, 8)})
sns.lineplot(x=df_country.index, y=df_country)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='traffic-chile'>

# %%
temp = seasonal_decompose(df_country.asfreq(freq='d'))
temp.plot()

# %%
window_size = 14
plot_acf(df_country.asfreq(freq='d'), lags=window_size)

# %%
# Tidak ada trend, namun memiliki seasonal

# %%
df_country = df_country.to_numpy().reshape(-1,1)

# %%
# Memisahkan Train, Validasi, Test

# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0, 1))
df_scaled = sc.fit_transform(df_country)

# %%
xdata = []
ydata = []

for i in range(window_size, len(df_scaled)):
    xdata.append(df_scaled[i-window_size:i])
    ydata.append(df_scaled[i])

xdata, ydata = np.array(xdata), np.array(ydata)

# %%
xdata = np.reshape(xdata, (xdata.shape[0], xdata.shape[1], 1))

# %%
xtrain, xval, xtest = xdata[0:-(window_size*10)
                            ], xdata[-(window_size*10):-(window_size*5)], xdata[-(window_size*5):]

ytrain, yval, ytest = ydata[0:-(window_size*10)
                            ], ydata[-(window_size*10):-(window_size*5)], ydata[-(window_size*5):]

# %%
xdata.shape
# Out:
# (248, 14, 1)

# %%
ydata.shape
# Out:
# (248, 1)

# %%
batch_size = 8

# %%
tf.keras.backend.clear_session()

model_tune = tf.keras.models.Sequential([
    tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                           input_shape=[window_size]),
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(200, return_sequences=True)),
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(200, return_sequences=True)),
    # tf.keras.layers.Bidirectional(
    #     tf.keras.layers.LSTM(200, return_sequences=True)),
    # tf.keras.layers.Bidirectional(
    #     tf.keras.layers.LSTM(200, return_sequences=True)),
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(200)),
    tf.keras.layers.Dense(1)
])

# Print the model summary
model_tune.summary()

# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-4 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(momentum=0.9)

# Set the training parameters
model_tune.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer, metrics=["mae"])

# Train the model
history = model_tune.fit(xtrain, ytrain, validation_data=(xval, yval), epochs=100, batch_size=batch_size, validation_batch_size=batch_size, callbacks=[lr_schedule])
# Out:
# 2022-07-24 23:12:40.952698: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-24 23:12:40.953120: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-07-24 23:12:40.953205: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-07-24 23:12:40.953283: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-07-24 23:12:40.953359: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-07-24 23:12:40.953434: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-07-24 23:12:40.953510: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-07-24 23:12:40.953583: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-07-24 23:12:40.953658: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-07-24 23:12:40.953669: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-07-24 23:12:40.954256: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lambda (Lambda)             (None, 14, 1)             0
#
#  bidirectional (Bidirectiona  (None, 14, 400)          323200
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 14, 400)          961600
#  nal)
#
#  bidirectional_2 (Bidirectio  (None, 400)              961600
#  nal)
#
#  dense (Dense)               (None, 1)                 401
#
# =================================================================
# Total params: 2,246,801
# Trainable params: 2,246,801
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 14/14 [==============================] - 13s 319ms/step - loss: 0.0277 - mae: 0.2205 - val_loss: 0.0584 - val_mae: 0.3256 - lr: 1.0000e-04
# Epoch 2/100
# 14/14 [==============================] - 2s 163ms/step - loss: 0.0256 - mae: 0.2106 - val_loss: 0.0544 - val_mae: 0.3131 - lr: 1.1220e-04
# Epoch 3/100
# 14/14 [==============================] - 2s 154ms/step - loss: 0.0229 - mae: 0.1975 - val_loss: 0.0500 - val_mae: 0.2987 - lr: 1.2589e-04
# Epoch 4/100
# 14/14 [==============================] - 2s 149ms/step - loss: 0.0201 - mae: 0.1833 - val_loss: 0.0455 - val_mae: 0.2833 - lr: 1.4125e-04
# Epoch 5/100
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0174 - mae: 0.1682 - val_loss: 0.0411 - val_mae: 0.2673 - lr: 1.5849e-04
# Epoch 6/100
# 14/14 [==============================] - 2s 168ms/step - loss: 0.0148 - mae: 0.1531 - val_loss: 0.0370 - val_mae: 0.2513 - lr: 1.7783e-04
# Epoch 7/100
# 14/14 [==============================] - 2s 154ms/step - loss: 0.0125 - mae: 0.1382 - val_loss: 0.0329 - val_mae: 0.2347 - lr: 1.9953e-04
# Epoch 8/100
# 14/14 [==============================] - 2s 153ms/step - loss: 0.0105 - mae: 0.1249 - val_loss: 0.0291 - val_mae: 0.2183 - lr: 2.2387e-04
# Epoch 9/100
# 14/14 [==============================] - 2s 153ms/step - loss: 0.0086 - mae: 0.1118 - val_loss: 0.0258 - val_mae: 0.2031 - lr: 2.5119e-04
# Epoch 10/100
# 14/14 [==============================] - 2s 152ms/step - loss: 0.0072 - mae: 0.1007 - val_loss: 0.0228 - val_mae: 0.1883 - lr: 2.8184e-04
# Epoch 11/100
# 14/14 [==============================] - 2s 154ms/step - loss: 0.0060 - mae: 0.0911 - val_loss: 0.0202 - val_mae: 0.1742 - lr: 3.1623e-04
# Epoch 12/100
# 14/14 [==============================] - 2s 153ms/step - loss: 0.0051 - mae: 0.0829 - val_loss: 0.0179 - val_mae: 0.1621 - lr: 3.5481e-04
# Epoch 13/100
# 14/14 [==============================] - 2s 157ms/step - loss: 0.0044 - mae: 0.0774 - val_loss: 0.0161 - val_mae: 0.1524 - lr: 3.9811e-04
# Epoch 14/100
# 14/14 [==============================] - 2s 165ms/step - loss: 0.0183 - mae: 0.1660 - val_loss: 0.0055 - val_mae: 0.0839 - lr: 1.9953
# Epoch 88/100
# 14/14 [==============================] - 2s 158ms/step - loss: 32.0963 - mae: 32.4913 - val_loss: 218.7448 - val_mae: 219.2448 - lr: 2.2387
# Epoch 89/100
# 14/14 [==============================] - 2s 157ms/step - loss: 355.0332 - mae: 355.5332 - val_loss: 661.6802 - val_mae: 662.1802 - lr: 2.5119
# Epoch 90/100
# 14/14 [==============================] - 2s 159ms/step - loss: 231.7463 - mae: 232.2463 - val_loss: 237.8524 - val_mae: 238.3524 - lr: 2.8184
# Epoch 91/100
# 14/14 [==============================] - 2s 163ms/step - loss: 306.7889 - mae: 307.2889 - val_loss: 158.0497 - val_mae: 158.5497 - lr: 3.1623
# Epoch 92/100
# 14/14 [==============================] - 3s 199ms/step - loss: 323.7711 - mae: 324.2711 - val_loss: 87.0222 - val_mae: 87.5222 - lr: 3.5481
# Epoch 93/100
# 14/14 [==============================] - 3s 195ms/step - loss: 248.2923 - mae: 248.7923 - val_loss: 399.5012 - val_mae: 400.0012 - lr: 3.9811
# Epoch 94/100
# 14/14 [==============================] - 2s 162ms/step - loss: 236.9496 - mae: 237.4496 - val_loss: 198.8589 - val_mae: 199.3589 - lr: 4.4668
# Epoch 95/100
# 14/14 [==============================] - 2s 160ms/step - loss: 249.8104 - mae: 250.3104 - val_loss: 1.0829 - val_mae: 1.5829 - lr: 5.0119
# Epoch 96/100
# 14/14 [==============================] - 2s 161ms/step - loss: 326.9807 - mae: 327.4807 - val_loss: 523.0409 - val_mae: 523.5409 - lr: 5.6234
# Epoch 97/100
# 14/14 [==============================] - 2s 160ms/step - loss: 438.4148 - mae: 438.9148 - val_loss: 463.5787 - val_mae: 464.0787 - lr: 6.3096
# Epoch 98/100
# 14/14 [==============================] - 2s 157ms/step - loss: 480.1108 - mae: 480.6108 - val_loss: 268.1379 - val_mae: 268.6379 - lr: 7.0795
# Epoch 99/100
# 14/14 [==============================] - 2s 163ms/step - loss: 399.9945 - mae: 400.4945 - val_loss: 862.2186 - val_mae: 862.7186 - lr: 7.9433
# Epoch 100/100
# 14/14 [==============================] - 2s 167ms/step - loss: 634.7978 - mae: 635.2978 - val_loss: 283.9159 - val_mae: 284.4159 - lr: 8.9125

# %%
# Define the learning rate array
lrs = 1e-4 * (10 ** (np.arange(100) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the loss in log scale
plt.semilogx(lrs, history.history["loss"])

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-4, 10, 0, 1])
# Out:
# (0.0001, 10.0, 0.0, 1.0)

# %%
tf.keras.backend.clear_session()

# %%
# Build the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                           input_shape=[window_size]),
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(200, return_sequences=True)),
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(200, return_sequences=True)),
    # tf.keras.layers.Bidirectional(
    #     tf.keras.layers.LSTM(200, return_sequences=True)),
    # tf.keras.layers.Bidirectional(
    #     tf.keras.layers.LSTM(200, return_sequences=True)),
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(200)),
    tf.keras.layers.Dense(1)
])

# Set the learning rate
learning_rate = 1e-1

# Set the optimizer 
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# Train the model
history = model.fit(xtrain, ytrain, validation_data=(xval, yval), epochs=100, batch_size=batch_size, validation_batch_size=batch_size)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 13s 315ms/step - loss: 0.0089 - mae: 0.1114 - val_loss: 0.0059 - val_mae: 0.0877
# Epoch 2/100
# 14/14 [==============================] - 2s 150ms/step - loss: 0.0042 - mae: 0.0763 - val_loss: 0.0092 - val_mae: 0.1118
# Epoch 3/100
# 14/14 [==============================] - 2s 146ms/step - loss: 0.0037 - mae: 0.0697 - val_loss: 0.0098 - val_mae: 0.1156
# Epoch 4/100
# 14/14 [==============================] - 2s 149ms/step - loss: 0.0034 - mae: 0.0686 - val_loss: 0.0136 - val_mae: 0.1392
# Epoch 5/100
# 14/14 [==============================] - 2s 149ms/step - loss: 0.0041 - mae: 0.0735 - val_loss: 0.0067 - val_mae: 0.0948
# Epoch 6/100
# 14/14 [==============================] - 2s 151ms/step - loss: 0.0039 - mae: 0.0717 - val_loss: 0.0159 - val_mae: 0.1519
# Epoch 7/100
# 14/14 [==============================] - 2s 151ms/step - loss: 0.0038 - mae: 0.0695 - val_loss: 0.0081 - val_mae: 0.1052
# Epoch 8/100
# 14/14 [==============================] - 2s 151ms/step - loss: 0.0038 - mae: 0.0691 - val_loss: 0.0128 - val_mae: 0.1346
# Epoch 9/100
# 14/14 [==============================] - 2s 151ms/step - loss: 0.0047 - mae: 0.0797 - val_loss: 0.0154 - val_mae: 0.1496
# Epoch 10/100
# 14/14 [==============================] - 2s 151ms/step - loss: 0.0051 - mae: 0.0821 - val_loss: 0.0072 - val_mae: 0.0984
# Epoch 11/100
# 14/14 [==============================] - 2s 152ms/step - loss: 0.0050 - mae: 0.0792 - val_loss: 0.0060 - val_mae: 0.0881
# Epoch 12/100
# 14/14 [==============================] - 2s 152ms/step - loss: 0.0037 - mae: 0.0698 - val_loss: 0.0117 - val_mae: 0.1285
# Epoch 13/100
# 14/14 [==============================] - 2s 167ms/step - loss: 0.0034 - mae: 0.0675 - val_loss: 0.0095 - val_mae: 0.1141
# Epoch 14/100
# 14/14 [==============================] - 2s 149ms/step - loss: 0.0032 - mae: 0.0660 - val_loss: 0.0094 - val_mae: 0.1135
# Epoch 15/100
# 14/14 [==============================] - 2s 157ms/step - loss: 0.0033 - mae: 0.0678 - val_loss: 0.0082 - val_mae: 0.1061
# Epoch 16/100
# 14/14 [==============================] - 2s 150ms/step - loss: 0.0034 - mae: 0.0684 - val_loss: 0.0090 - val_mae: 0.1117
# Epoch 17/100
# 14/14 [==============================] - 2s 148ms/step - loss: 0.0033 - mae: 0.0674 - val_loss: 0.0069 - val_mae: 0.0964
# Epoch 18/100
# 14/14 [==============================] - 2s 149ms/step - loss: 0.0035 - mae: 0.0694 - val_loss: 0.0059 - val_mae: 0.0878
# Epoch 19/100
# 14/14 [==============================] - 2s 148ms/step - loss: 0.0041 - mae: 0.0714 - val_loss: 0.0055 - val_mae: 0.0835
# Epoch 20/100
# 14/14 [==============================] - 2s 150ms/step - loss: 0.0037 - mae: 0.0691 - val_loss: 0.0074 - val_mae: 0.1003
# Epoch 21/100
# 14/14 [==============================] - 2s 157ms/step - loss: 0.0042 - mae: 0.0746 - val_loss: 0.0135 - val_mae: 0.1392
# Epoch 22/100
# 14/14 [==============================] - 2s 167ms/step - loss: 0.0034 - mae: 0.0674 - val_loss: 0.0085 - val_mae: 0.1081
# Epoch 23/100
# 14/14 [==============================] - 2s 164ms/step - loss: 0.0042 - mae: 0.0707 - val_loss: 0.0112 - val_mae: 0.1254
# Epoch 24/100
# 14/14 [==============================] - 2s 168ms/step - loss: 0.0036 - mae: 0.0674 - val_loss: 0.0162 - val_mae: 0.1536
# Epoch 25/100
# 14/14 [==============================] - 2s 173ms/step - loss: 0.0049 - mae: 0.0811 - val_loss: 0.0153 - val_mae: 0.1488
# Epoch 26/100
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0048 - mae: 0.0792 - val_loss: 0.0200 - val_mae: 0.1741
# Epoch 27/100
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0063 - mae: 0.0930 - val_loss: 0.0132 - val_mae: 0.1374
# Epoch 28/100
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0046 - mae: 0.0790 - val_loss: 0.0080 - val_mae: 0.1042
# Epoch 29/100
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0041 - mae: 0.0743 - val_loss: 0.0094 - val_mae: 0.1142
# Epoch 30/100
# 14/14 [==============================] - 2s 158ms/step - loss: 0.0033 - mae: 0.0659 - val_loss: 0.0098 - val_mae: 0.1164
# Epoch 31/100
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0034 - mae: 0.0681 - val_loss: 0.0070 - val_mae: 0.0972
# Epoch 32/100
# 14/14 [==============================] - 2s 159ms/step - loss: 0.0032 - mae: 0.0656 - val_loss: 0.0121 - val_mae: 0.1308
# Epoch 33/100
# 14/14 [==============================] - 2s 157ms/step - loss: 0.0034 - mae: 0.0668 - val_loss: 0.0117 - val_mae: 0.1287
# Epoch 34/100
# 14/14 [==============================] - 2s 158ms/step - loss: 0.0033 - mae: 0.0671 - val_loss: 0.0086 - val_mae: 0.1090
# Epoch 35/100
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0032 - mae: 0.0649 - val_loss: 0.0121 - val_mae: 0.1309
# Epoch 36/100
# 14/14 [==============================] - 2s 159ms/step - loss: 0.0036 - mae: 0.0708 - val_loss: 0.0115 - val_mae: 0.1275
# Epoch 37/100
# 14/14 [==============================] - 2s 159ms/step - loss: 0.0039 - mae: 0.0709 - val_loss: 0.0070 - val_mae: 0.0969
# Epoch 38/100
# 14/14 [==============================] - 2s 173ms/step - loss: 0.0032 - mae: 0.0648 - val_loss: 0.0107 - val_mae: 0.1223
# Epoch 39/100
# 14/14 [==============================] - 2s 159ms/step - loss: 0.0033 - mae: 0.0667 - val_loss: 0.0102 - val_mae: 0.1191
# Epoch 40/100
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0032 - mae: 0.0662 - val_loss: 0.0070 - val_mae: 0.0975
# Epoch 41/100
# 14/14 [==============================] - 2s 156ms/step - loss: 0.0031 - mae: 0.0641 - val_loss: 0.0088 - val_mae: 0.1105
# Epoch 42/100
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0034 - mae: 0.0676 - val_loss: 0.0092 - val_mae: 0.1132
# Epoch 43/100
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0034 - mae: 0.0671 - val_loss: 0.0070 - val_mae: 0.0976
# Epoch 44/100
# 14/14 [==============================] - 2s 159ms/step - loss: 0.0032 - mae: 0.0638 - val_loss: 0.0091 - val_mae: 0.1129
# Epoch 45/100
# 14/14 [==============================] - 2s 163ms/step - loss: 0.0036 - mae: 0.0691 - val_loss: 0.0102 - val_mae: 0.1195
# Epoch 46/100
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0034 - mae: 0.0672 - val_loss: 0.0067 - val_mae: 0.0950
# Epoch 47/100
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0031 - mae: 0.0639 - val_loss: 0.0086 - val_mae: 0.1090
# Epoch 48/100
# 14/14 [==============================] - 2s 165ms/step - loss: 0.0032 - mae: 0.0653 - val_loss: 0.0072 - val_mae: 0.0989
# Epoch 49/100
# 14/14 [==============================] - 2s 162ms/step - loss: 0.0033 - mae: 0.0656 - val_loss: 0.0092 - val_mae: 0.1134
# Epoch 50/100
# 14/14 [==============================] - 2s 177ms/step - loss: 0.0033 - mae: 0.0663 - val_loss: 0.0078 - val_mae: 0.1034
# Epoch 51/100
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0033 - mae: 0.0661 - val_loss: 0.0084 - val_mae: 0.1082
# Epoch 52/100
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0033 - mae: 0.0647 - val_loss: 0.0071 - val_mae: 0.0985
# Epoch 53/100
# 14/14 [==============================] - 2s 159ms/step - loss: 0.0034 - mae: 0.0655 - val_loss: 0.0078 - val_mae: 0.1038
# Epoch 54/100
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0033 - mae: 0.0668 - val_loss: 0.0062 - val_mae: 0.0902
# Epoch 55/100
# 14/14 [==============================] - 2s 162ms/step - loss: 0.0034 - mae: 0.0680 - val_loss: 0.0057 - val_mae: 0.0862
# Epoch 56/100
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0037 - mae: 0.0678 - val_loss: 0.0075 - val_mae: 0.1012
# Epoch 57/100
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0033 - mae: 0.0675 - val_loss: 0.0073 - val_mae: 0.0996
# Epoch 58/100
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0034 - mae: 0.0676 - val_loss: 0.0075 - val_mae: 0.1017
# Epoch 59/100
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0032 - mae: 0.0646 - val_loss: 0.0085 - val_mae: 0.1088
# Epoch 60/100
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0029 - mae: 0.0619 - val_loss: 0.0056 - val_mae: 0.0845
# Epoch 61/100
# 14/14 [==============================] - 2s 159ms/step - loss: 0.0033 - mae: 0.0659 - val_loss: 0.0059 - val_mae: 0.0877
# Epoch 62/100
# 14/14 [==============================] - 2s 179ms/step - loss: 0.0032 - mae: 0.0644 - val_loss: 0.0075 - val_mae: 0.1015
# Epoch 63/100
# 14/14 [==============================] - 2s 163ms/step - loss: 0.0031 - mae: 0.0638 - val_loss: 0.0114 - val_mae: 0.1272
# Epoch 64/100
# 14/14 [==============================] - 2s 162ms/step - loss: 0.0037 - mae: 0.0699 - val_loss: 0.0098 - val_mae: 0.1174
# Epoch 65/100
# 14/14 [==============================] - 2s 162ms/step - loss: 0.0037 - mae: 0.0714 - val_loss: 0.0067 - val_mae: 0.0948
# Epoch 66/100
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0030 - mae: 0.0609 - val_loss: 0.0085 - val_mae: 0.1086
# Epoch 67/100
# 14/14 [==============================] - 2s 169ms/step - loss: 0.0031 - mae: 0.0640 - val_loss: 0.0072 - val_mae: 0.0993
# Epoch 68/100
# 14/14 [==============================] - 2s 173ms/step - loss: 0.0032 - mae: 0.0647 - val_loss: 0.0066 - val_mae: 0.0946
# Epoch 69/100
# 14/14 [==============================] - 2s 171ms/step - loss: 0.0037 - mae: 0.0692 - val_loss: 0.0060 - val_mae: 0.0892
# Epoch 70/100
# 14/14 [==============================] - 2s 163ms/step - loss: 0.0038 - mae: 0.0707 - val_loss: 0.0056 - val_mae: 0.0843
# Epoch 71/100
# 14/14 [==============================] - 2s 164ms/step - loss: 0.0050 - mae: 0.0815 - val_loss: 0.0054 - val_mae: 0.0827
# Epoch 72/100
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0034 - mae: 0.0688 - val_loss: 0.0066 - val_mae: 0.0937
# Epoch 73/100
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0031 - mae: 0.0644 - val_loss: 0.0063 - val_mae: 0.0911
# Epoch 74/100
# 14/14 [==============================] - 3s 188ms/step - loss: 0.0035 - mae: 0.0656 - val_loss: 0.0056 - val_mae: 0.0844
# Epoch 75/100
# 14/14 [==============================] - 2s 173ms/step - loss: 0.0040 - mae: 0.0727 - val_loss: 0.0079 - val_mae: 0.1044
# Epoch 76/100
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0037 - mae: 0.0686 - val_loss: 0.0060 - val_mae: 0.0891
# Epoch 77/100
# 14/14 [==============================] - 2s 169ms/step - loss: 0.0031 - mae: 0.0635 - val_loss: 0.0072 - val_mae: 0.0989
# Epoch 78/100
# 14/14 [==============================] - 2s 163ms/step - loss: 0.0031 - mae: 0.0636 - val_loss: 0.0054 - val_mae: 0.0827
# Epoch 79/100
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0033 - mae: 0.0658 - val_loss: 0.0085 - val_mae: 0.1090
# Epoch 80/100
# 14/14 [==============================] - 2s 162ms/step - loss: 0.0033 - mae: 0.0661 - val_loss: 0.0079 - val_mae: 0.1044
# Epoch 81/100
# 14/14 [==============================] - 2s 164ms/step - loss: 0.0030 - mae: 0.0629 - val_loss: 0.0068 - val_mae: 0.0959
# Epoch 82/100
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0030 - mae: 0.0607 - val_loss: 0.0112 - val_mae: 0.1259
# Epoch 83/100
# 14/14 [==============================] - 2s 163ms/step - loss: 0.0032 - mae: 0.0644 - val_loss: 0.0080 - val_mae: 0.1049
# Epoch 84/100
# 14/14 [==============================] - 2s 164ms/step - loss: 0.0031 - mae: 0.0645 - val_loss: 0.0089 - val_mae: 0.1119
# Epoch 85/100
# 14/14 [==============================] - 3s 180ms/step - loss: 0.0046 - mae: 0.0774 - val_loss: 0.0103 - val_mae: 0.1205
# Epoch 86/100
# 14/14 [==============================] - 2s 162ms/step - loss: 0.0044 - mae: 0.0778 - val_loss: 0.0114 - val_mae: 0.1272
# Epoch 87/100
# 14/14 [==============================] - 2s 162ms/step - loss: 0.0039 - mae: 0.0705 - val_loss: 0.0062 - val_mae: 0.0909
# Epoch 88/100
# 14/14 [==============================] - 2s 162ms/step - loss: 0.0029 - mae: 0.0621 - val_loss: 0.0086 - val_mae: 0.1091
# Epoch 89/100
# 14/14 [==============================] - 2s 164ms/step - loss: 0.0031 - mae: 0.0629 - val_loss: 0.0073 - val_mae: 0.1000
# Epoch 90/100
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0031 - mae: 0.0656 - val_loss: 0.0056 - val_mae: 0.0851
# Epoch 91/100
# 14/14 [==============================] - 2s 169ms/step - loss: 0.0040 - mae: 0.0701 - val_loss: 0.0054 - val_mae: 0.0828
# Epoch 92/100
# 14/14 [==============================] - 2s 162ms/step - loss: 0.0033 - mae: 0.0681 - val_loss: 0.0083 - val_mae: 0.1070
# Epoch 93/100
# 14/14 [==============================] - 2s 159ms/step - loss: 0.0031 - mae: 0.0648 - val_loss: 0.0061 - val_mae: 0.0895
# Epoch 94/100
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0031 - mae: 0.0637 - val_loss: 0.0068 - val_mae: 0.0959
# Epoch 95/100
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0032 - mae: 0.0649 - val_loss: 0.0069 - val_mae: 0.0968
# Epoch 96/100
# 14/14 [==============================] - 2s 162ms/step - loss: 0.0030 - mae: 0.0639 - val_loss: 0.0060 - val_mae: 0.0889
# Epoch 97/100
# 14/14 [==============================] - 2s 179ms/step - loss: 0.0031 - mae: 0.0624 - val_loss: 0.0081 - val_mae: 0.1060
# Epoch 98/100
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0034 - mae: 0.0671 - val_loss: 0.0068 - val_mae: 0.0957
# Epoch 99/100
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0033 - mae: 0.0655 - val_loss: 0.0074 - val_mae: 0.1002
# Epoch 100/100
# 14/14 [==============================] - 2s 162ms/step - loss: 0.0030 - mae: 0.0625 - val_loss: 0.0060 - val_mae: 0.0890

# %%
# summarize history for accuracy
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('model mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
ypred = model.predict(xdata)

plt.plot(ypred)
plt.plot(ydata)
plt.title('prediksi vs aktual semua data')
plt.ylabel('traffic')
plt.xlabel('series')
plt.legend(['prediksi', 'aktual'], loc='upper left')
plt.show()
# Out:
# 8/8 [==============================] - 3s 64ms/step

# %%
ypred = model.predict(xtest)

plt.plot(ypred)
plt.plot(ytest)
plt.title('prediksi vs aktual data testing')
plt.ylabel('traffic')
plt.xlabel('series')
plt.legend(['prediksi', 'aktual'], loc='upper left')
plt.show()
# Out:
# 3/3 [==============================] - 0s 52ms/step
